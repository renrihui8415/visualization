# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from PIL import Image
import requests
from io import BytesIO

response = requests.get(' https://upload.wikimedia.org/wikipedia/en/c/cb/Monkey_D_Luffy.png')
image_file = BytesIO(response.content)
image = Image.open(image_file)

x = np.array(['Luffy','Zoro','Nami','Usopp','Sanji'])
y2= np.array([170, 100, 90, 120, 50])

# %%
fig, ax = plt.subplots(figure=(7,3))
ax.plot(x,y2,color ='red')

ax_image = fig.add_axes([0.1, #x
                         0.11, #y
                         0.15, # wide
                         0.35]) # height

ax_image.imshow(image)
ax_image.axis('off')
# Out:
# (-0.5, 219.5, 425.5, -0.5)

# %%
## let's make a real fancy plot for fun

##collect our images for each datapoint
response = requests.get('https://upload.wikimedia.org/wikipedia/en/c/cb/Monkey_D_Luffy.png')
image_file = BytesIO(response.content)
luffyimg = Image.open(image_file)

response = requests.get('https://static.wikia.nocookie.net/p__/images/6/6e/Roronoa_Zoro_Post_Timeskip.png/revision/latest?cb=20190529044836&path-prefix=protagonist')
image_file = BytesIO(response.content)
zoroimg = Image.open(image_file)

response = requests.get('https://static.wikia.nocookie.net/p__/images/f/f0/Nami_Waifuuu.png/revision/latest?cb=20190113023031&path-prefix=protagonist')
image_file = BytesIO(response.content)
namiimg = Image.open(image_file)

response = requests.get('https://static.wikia.nocookie.net/p__/images/5/53/Usopp.png/revision/latest?cb=20190529045324&path-prefix=protagonist')
image_file = BytesIO(response.content)
usoppimg = Image.open(image_file)

response = requests.get('https://static.wikia.nocookie.net/p__/images/b/b0/Sanji_Vector.png/revision/latest?cb=20190426102221&path-prefix=protagonist')
image_file = BytesIO(response.content)
sanjiimg = Image.open(image_file)

##remake our plot 
fig, ax = plt.subplots(figsize=(7, 3),
                      layout = "constrained")
ax.plot(x, y2,
       color = "red",
       alpha = 0.5,
       linestyle = '--')

##add axes containers for each image
ax_luf = fig.add_axes([0.05, ##x coordinate (ON FIGURE, NOT AXES)
                         0.55, ##y coordinate (ON FIGURE, NOT AXES)
                         0.15, ##image width
                         0.35] ##image height
                       )

ax_zoro = fig.add_axes([0.25, ##x coordinate (ON FIGURE, NOT AXES)
                         0.2, ##y coordinate (ON FIGURE, NOT AXES)
                         0.15, ##image width
                         0.35] ##image height
                       )

ax_nami = fig.add_axes([0.45, ##x coordinate (ON FIGURE, NOT AXES)
                         0.12, ##y coordinate (ON FIGURE, NOT AXES)
                         0.15, ##image width
                         0.35] ##image height
                       )


ax_usopp = fig.add_axes([0.65, ##x coordinate (ON FIGURE, NOT AXES)
                         0.35, ##y coordinate (ON FIGURE, NOT AXES)
                         0.15, ##image width
                         0.35] ##image height
                       )

ax_sanji = fig.add_axes([0.87, ##x coordinate (ON FIGURE, NOT AXES)
                         0.11, ##y coordinate (ON FIGURE, NOT AXES)
                         0.15, ##image width
                         0.35] ##image height
                       )

##now use imshow() to add our images we prepped before
ax_luf.imshow(luffyimg)
ax_luf.axis('off')  

ax_zoro.imshow(zoroimg)
ax_zoro.axis('off')

ax_nami.imshow(namiimg)
ax_nami.axis('off')

ax_usopp.imshow(usoppimg)
ax_usopp.axis('off')

ax_sanji.imshow(sanjiimg)
ax_sanji.axis('off')


##now add labels and titles to our plot
ax.set_xlabel('Characters', fontsize = 14)
ax.set_ylabel('Power', fontsize = 14)
ax.set_title('Power Levels of Pirate Crew', fontsize = 18)
           
##show plot
plt.show()

# %% [markdown]
# Intended Audience

# %% [markdown]
# https://podio.com/site/creative-routines

# %% [markdown]
# Accessibility
#
# - Color
#     - (Color Blindness Simulator https://www.color-blindness.com/coblis-color-blindness-simulator/)
#     - Brightness and Contrast (Overly bright colors and low contrast are to be avoided) (check contrast: https://webaim.org/resources/contrastchecker/)
#     - Viridis package (https://cran.r-project.org/web/packages/viridis/vignettes/intro-to-viridis.html)
# -  Text
#     - Labels and legends
#     - Typeface or font (sans-serif)
#     - Font size and spacing, at least 12 point size, better monospaced,
#     - Alt-text, simple

# %% [markdown]
# 4 Types of descriptive content
# - chart elements
# - statistics , mean
# - trend
# - domain insights

# %% [markdown]
# Based on https://podio.com/site/creative-routines
#
# - 1. Chart Elements
#
# The visualization uses a timeline chart to depict the daily routines of various famous creatives.
#
# Key elements include:
#
# **Horizontal Bars**: Each individual’s day is represented by a horizontal bar broken into color-coded segments.
#
# **Color Coding**: Different activities are represented by different colors (e.g., blue for sleep, green for creative work, yellow for leisure, etc.).
#
#
# - 2. Descriptive Statistics
#
# The visualization provides implicit descriptive statistics by showing the proportion of time allocated to various activities:
#
# **Sleep**: Many creatives allocate a significant portion of their day to sleep, typically between 6-8 hours.
#
# **Work**: The time dedicated to creative work varies widely, with some spending up to 10 hours a day.
#
# **Leisure and Exercise**: These activities often occupy around 2-4 hours of the day.
#
# **Administration and Other Activities**: Time spent on these can range from minimal to several hours, depending on the individual.
#
# - 3. Trends and Patterns
#
# The visualization highlights several trends and patterns in the daily routines of these
# creatives:
#
# **Consistency in Sleep**: Despite varied schedules, most creatives ensure a regular sleep pattern.
#
# **Morning vs. Night Work**: Some individuals, like Haruki Murakami, start their creative work early in the morning, while others, like Franz Kafka, work late into the night.
#
# **Balanced Lifestyle:** Many creatives integrate breaks and leisure activities into their routines, indicating the importance of rest and relaxation alongside work.
#
# - 4. Domain Insights
#
# The visualization provides insights into the lifestyles and work habits of successful creatives, which can be valuable for understanding productivity and creativity:
#
# **Structured Routine**: Successful creatives often follow a structured routine, balancing work with rest and leisure.
#
# **Importance of Rest**: Regular sleep and breaks are common, highlighting the importance of rest in maintaining creativity.
#
# **Personalized Schedules**: There is no one-size-fits-all approach; each individual tailors their routine to fit their personal needs and work style, demonstrating the importance of finding what works best for oneself.

# %% [markdown]
# References:
#
# - https://rgd.ca/working-in-design/resources/accessability-2-a-practical-handbook-on-accessible-graphic-design
#
# - https://a11y.canada.ca/en/

# %% [markdown]
# Advocacy

# %% [markdown]
# - Rational appeal
# - Moral appeal
# - Emotional appeal
